# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Data Analysis with Python <br>Project - 1</p><h1> - Traffic Police Stops <img src="https://docs.google.com/uc?id=17CPCwi3_VvzcS87TOsh4_U8eExOhL6Ki" class="img-fluid" alt="CLRSWY" width="200" height="100">

# %% [markdown]
# Before beginning your analysis, it is critical that you first examine and clean the dataset, to make working with it a more efficient process. You will practice fixing data types, handling missing values, and dropping columns and rows while learning about the Stanford Open Policing Project dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Examining the dataset

# %% [markdown]
# You'll be analyzing a dataset of traffic stops in Rhode Island that was collected by the Stanford Open Policing Project.

# %% [markdown]
# Before beginning your analysis, it's important that you familiarize yourself with the dataset. You'll read the dataset into pandas, examine the first few rows, and then count the number of missing values.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Import pandas using the alias ``pd``.
# *   Read the file police.csv into a DataFrame named ``ri``
# *   Examine the first 5 rows of the ``DataFrame`` (known as the ``"head"``).
# *   Count the number of missing values in each column: Use ``.isnull()`` to check which ``DataFrame`` elements are missing, and then take the ``.sum()`` to count the number of ``True`` values in each column.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("police.csv")
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
# 3             False              NaN         NaN            False
# 4             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0     Citation       False      0-15 Min        False              False
# 1     Citation       False     16-30 Min        False              False
# 2          NaN         NaN           NaN          NaN              False
# 3     Citation       False      0-15 Min        False              False
# 4     Citation       False      0-15 Min        False              False
#
#    district
# 0   Zone K1
# 1   Zone X4
# 2   Zone X1
# 3   Zone X4
# 4   Zone X4
#
# [5 rows x 26 columns]

# %%
df.isnull()
# Out:
#            id  state  stop_date  stop_time  location_raw  county_name  \
# 0       False  False      False      False         False         True
# 1       False  False      False      False         False         True
# 2       False  False      False      False         False         True
# 3       False  False      False      False         False         True
# 4       False  False      False      False         False         True
# ...       ...    ...        ...        ...           ...          ...
# 509676  False  False       True       True         False         True
# 509677  False  False       True       True         False         True
# 509678  False  False       True       True         False         True
# 509679  False  False       True       True         False         True
# 509680  False  False       True       True         False         True
#
#         county_fips  fine_grained_location  police_department  driver_gender  \
# 0              True                   True              False          False
# 1              True                   True              False          False
# 2              True                   True              False           True
# 3              True                   True              False          False
# 4              True                   True              False          False
# ...             ...                    ...                ...            ...
# 509676         True                   True               True           True
# 509677         True                   True               True           True
# 509678         True                   True               True           True
# 509679         True                   True               True           True
# 509680         True                   True               True           True
#
#         ...  search_conducted  search_type_raw  search_type  contraband_found  \
# 0       ...             False             True         True             False
# 1       ...             False             True         True             False
# 2       ...             False             True         True             False
# 3       ...             False             True         True             False
# 4       ...             False             True         True             False
# ...     ...               ...              ...          ...               ...
# 509676  ...              True             True         True             False
# 509677  ...              True             True         True             False
# 509678  ...              True             True         True             False
# 509679  ...              True             True         True             False
# 509680  ...              True             True         True             False
#
#         stop_outcome  is_arrested  stop_duration  out_of_state  \
# 0              False        False          False         False
# 1              False        False          False         False
# 2               True         True           True          True
# 3              False        False          False         False
# 4              False        False          False         False
# ...              ...          ...            ...           ...
# 509676          True         True           True          True
# 509677          True         True           True          True
# 509678          True         True           True          True
# 509679          True         True           True          True
# 509680          True         True           True          True
#
#         drugs_related_stop  district
# 0                    False     False
# 1                    False     False
# 2                    False     False
# 3                    False     False
# 4                    False     False
# ...                    ...       ...
# 509676               False     False
# 509677               False     False
# 509678               False     False
# 509679               False     False
# 509680               False     False
#
# [509681 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
df["contraband_found"].value_counts()
# Out:
# False    503102
# True       6579
# Name: contraband_found, dtype: int64

# %%
df["drugs_related_stop"].value_counts()
# Out:
# False    504916
# True       4765
# Name: drugs_related_stop, dtype: int64

# %%
df["state"].value_counts()
# Out:
# RI    509681
# Name: state, dtype: int64

# %%
df.shape
# Out:
# (509681, 26)

# %% [markdown]
# ## Dropping columns

# %% [markdown]
# Often, a DataFrame will contain columns that are not useful to your analysis. Such columns should be dropped from the ``DataFrame``, to make it easier for you to focus on the remaining columns.
#
# You'll drop the ``county_name`` column because it only contains missing values, and you'll drop the ``state`` column because all of the traffic stops took place in one state (Rhode Island). Thus, these columns can be dropped because they contain no useful information.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``DataFrame``'s shape to find out the number of rows and columns.
#
# *   Drop the columns that almost consist of missing values.
#
# *   Examine the ``.shape`` again to verify that there are now two fewer columns.

# %%
df.drop(['county_name','state'], axis=1, inplace=True) # 'county_fips','fine_grained_location'

# %%
df
# Out:
#                    id   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# ...               ...         ...       ...          ...          ...
# 509676       RI-NA-06         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10         NaN       NaN      Zone NA          NaN
#
#         fine_grained_location police_department driver_gender  driver_age_raw  \
# 0                         NaN               600             M          1985.0
# 1                         NaN               500             M          1987.0
# 2                         NaN                 0           NaN             NaN
# 3                         NaN               500             M          1986.0
# 4                         NaN               500             M          1978.0
# ...                       ...               ...           ...             ...
# 509676                    NaN               NaN           NaN             NaN
# 509677                    NaN               NaN           NaN             NaN
# 509678                    NaN               NaN           NaN             NaN
# 509679                    NaN               NaN           NaN             NaN
# 509680                    NaN               NaN           NaN             NaN
#
#         driver_age  ... search_conducted search_type_raw search_type  \
# 0             20.0  ...            False             NaN         NaN
# 1             18.0  ...            False             NaN         NaN
# 2              NaN  ...            False             NaN         NaN
# 3             19.0  ...            False             NaN         NaN
# 4             27.0  ...            False             NaN         NaN
# ...            ...  ...              ...             ...         ...
# 509676         NaN  ...              NaN             NaN         NaN
# 509677         NaN  ...              NaN             NaN         NaN
# 509678         NaN  ...              NaN             NaN         NaN
# 509679         NaN  ...              NaN             NaN         NaN
# 509680         NaN  ...              NaN             NaN         NaN
#
#        contraband_found stop_outcome is_arrested stop_duration  out_of_state  \
# 0                 False     Citation       False      0-15 Min         False
# 1                 False     Citation       False     16-30 Min         False
# 2                 False          NaN         NaN           NaN           NaN
# 3                 False     Citation       False      0-15 Min         False
# 4                 False     Citation       False      0-15 Min         False
# ...                 ...          ...         ...           ...           ...
# 509676            False          NaN         NaN           NaN           NaN
# 509677            False          NaN         NaN           NaN           NaN
# 509678            False          NaN         NaN           NaN           NaN
# 509679            False          NaN         NaN           NaN           NaN
# 509680            False          NaN         NaN           NaN           NaN
#
#        drugs_related_stop district
# 0                   False  Zone K1
# 1                   False  Zone X4
# 2                   False  Zone X1
# 3                   False  Zone X4
# 4                   False  Zone X4
# ...                   ...      ...
# 509676              False  Zone NA
# 509677              False  Zone NA
# 509678              False  Zone NA
# 509679              False  Zone NA
# 509680              False  Zone NA
#
# [509681 rows x 24 columns]

# %%
df.shape
# Out:
# (509681, 24)

# %% [markdown]
# ## Dropping rows

# %% [markdown]
# When you know that a specific column will be critical to your analysis, and only a small fraction of rows are missing a value in that column, it often makes sense to remove those rows from the dataset.
#
# During this course, the ``driver_gender`` column will be critical to many of your analyses. Because only a small fraction of rows are missing ``driver_gender``, we'll drop those rows from the dataset.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Count the number of missing values in each column.
#
# *   Drop all rows that are missing ``driver_gender`` by passing the column name to the subset parameter of ``.dropna()``.
# *   Count the number of missing values in each column again, to verify that none of the remaining rows are missing ``driver_gender``.
# *   Examine the ``DataFrame``'s ``.shape`` to see how many rows and columns remain.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509681 entries, 0 to 509680
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     509681 non-null  object
#  1   stop_date              509671 non-null  object
#  2   stop_time              509671 non-null  object
#  3   location_raw           509681 non-null  object
#  4   county_fips            0 non-null       float64
#  5   fine_grained_location  0 non-null       float64
#  6   police_department      509671 non-null  object
#  7   driver_gender          480584 non-null  object
#  8   driver_age_raw         480632 non-null  float64
#  9   driver_age             478986 non-null  float64
#  10  driver_race_raw        480608 non-null  object
#  11  driver_race            480608 non-null  object
#  12  violation_raw          480608 non-null  object
#  13  violation              480608 non-null  object
#  14  search_conducted       509671 non-null  object
#  15  search_type_raw        17762 non-null   object
#  16  search_type            17762 non-null   object
#  17  contraband_found       509681 non-null  bool
#  18  stop_outcome           480608 non-null  object
#  19  is_arrested            480608 non-null  object
#  20  stop_duration          480608 non-null  object
#  21  out_of_state           479800 non-null  object
#  22  drugs_related_stop     509681 non-null  bool
#  23  district               509681 non-null  object
# dtypes: bool(2), float64(4), object(18)
# memory usage: 86.5+ MB

# %%
df.isnull().sum()
# Out:
# id                            0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
df = df.dropna(subset=['driver_gender'])

# %%
df
# Out:
#                    id   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006  2005-01-12     08:05      Zone X1          NaN
# ...               ...         ...       ...          ...          ...
# 509666  RI-2015-47061  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065  2015-12-31     23:48      Zone K3          NaN
#
#         fine_grained_location police_department driver_gender  driver_age_raw  \
# 0                         NaN               600             M          1985.0
# 1                         NaN               500             M          1987.0
# 3                         NaN               500             M          1986.0
# 4                         NaN               500             M          1978.0
# 5                         NaN                 0             M          1973.0
# ...                       ...               ...           ...             ...
# 509666                    NaN               0.0             M          1959.0
# 509667                    NaN             500.0             M          1988.0
# 509668                    NaN             200.0             M          1980.0
# 509669                    NaN             900.0             M          1984.0
# 509670                    NaN             300.0             M          1988.0
#
#         driver_age  ... search_conducted search_type_raw search_type  \
# 0             20.0  ...            False             NaN         NaN
# 1             18.0  ...            False             NaN         NaN
# 3             19.0  ...            False             NaN         NaN
# 4             27.0  ...            False             NaN         NaN
# 5             32.0  ...            False             NaN         NaN
# ...            ...  ...              ...             ...         ...
# 509666        56.0  ...            False             NaN         NaN
# 509667        27.0  ...            False             NaN         NaN
# 509668        35.0  ...            False             NaN         NaN
# 509669        31.0  ...            False             NaN         NaN
# 509670        27.0  ...            False             NaN         NaN
#
#        contraband_found stop_outcome is_arrested stop_duration  out_of_state  \
# 0                 False     Citation       False      0-15 Min         False
# 1                 False     Citation       False     16-30 Min         False
# 3                 False     Citation       False      0-15 Min         False
# 4                 False     Citation       False      0-15 Min         False
# 5                 False     Citation       False       30+ Min          True
# ...                 ...          ...         ...           ...           ...
# 509666            False     Citation       False      0-15 Min          True
# 509667            False     Citation       False      0-15 Min         False
# 509668            False     Citation       False      0-15 Min         False
# 509669            False     Citation       False      0-15 Min         False
# 509670            False     Citation       False      0-15 Min         False
#
#        drugs_related_stop district
# 0                   False  Zone K1
# 1                   False  Zone X4
# 3                   False  Zone X4
# 4                   False  Zone X4
# 5                   False  Zone X1
# ...                   ...      ...
# 509666              False  Zone X1
# 509667              False  Zone X4
# 509668              False  Zone X3
# 509669              False  Zone K2
# 509670              False  Zone K3
#
# [480584 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# id                            0
# stop_date                     0
# stop_time                     0
# location_raw                  0
# county_fips              480584
# fine_grained_location    480584
# police_department             0
# driver_gender                 0
# driver_age_raw                1
# driver_age                 1638
# driver_race_raw               0
# driver_race                   0
# violation_raw                 0
# violation                     0
# search_conducted              0
# search_type_raw          462822
# search_type              462822
# contraband_found              0
# stop_outcome                  0
# is_arrested                   0
# stop_duration                 0
# out_of_state                808
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
df.shape
# Out:
# (480584, 24)

# %% [markdown]
# ## Fixing a data type

# %% [markdown]
# We know that the ``is_arrested`` column currently has the ``object`` data type. In this exercise, we'll change the data type to ``bool``, which is the most suitable type for a column containing ``True`` and ``False`` values.
#
# Fixing the data type will enable us to use mathematical operations on the ``is_arrested`` column that would not be possible otherwise.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the head of the ``is_arrested`` column to verify that it contains ``True`` and ``False`` values.
# *   Check the current data type of ``is_arrested``.
# *   Use the ``.astype()`` method to convert ``is_arrested`` to a ``bool`` column.
# *   Check the new data type of ``is_arrested``, to confirm that it is now a ``bool`` column.

# %%
df["is_arrested"]
# Out:
# 0         False
# 1         False
# 3         False
# 4         False
# 5         False
#           ...
# 509666    False
# 509667    False
# 509668    False
# 509669    False
# 509670    False
# Name: is_arrested, Length: 480584, dtype: object

# %%
df["is_arrested"].dtypes
# Out:
# dtype('O')

# %%
df["is_arrested"] = df["is_arrested"].astype('bool')
# Out:
# <ipython-input-247-b4e75caa8051>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["is_arrested"] = df["is_arrested"].astype('bool')

# %%
df["is_arrested"].dtypes
# Out:
# dtype('bool')

# %% [markdown]
# ***

# %% [markdown]
# ## Combining object columns

# %% [markdown]
# Currently, the date and time of each traffic stop are stored in separate object columns: ``stop_date`` and ``stop_time``.
#
# You'll combine these two columns into a single column, and then convert it to ``datetime`` format. This will enable convenient date-based attributes that we'll use later in the course.

# %% [markdown]
# **INSTRUCTIONS**
#
# *    Use a string method to concatenate ``stop_date`` and ``stop_time`` (separated by a space), and store the result in ``combined``.
# *    Convert ``combined`` to ``datetime`` format, and store the result in a new column named ``stop_datetime``.
# *    Examine the ``DataFrame`` ``.dtypes`` to confirm that ``stop_datetime`` is a datetime column.

# %%
df.head()
# Out:
#               id   stop_date stop_time location_raw  county_fips  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1          NaN
#
#    fine_grained_location police_department driver_gender  driver_age_raw  \
# 0                    NaN               600             M          1985.0
# 1                    NaN               500             M          1987.0
# 3                    NaN               500             M          1986.0
# 4                    NaN               500             M          1978.0
# 5                    NaN                 0             M          1973.0
#
#    driver_age  ... search_conducted search_type_raw search_type  \
# 0        20.0  ...            False             NaN         NaN
# 1        18.0  ...            False             NaN         NaN
# 3        19.0  ...            False             NaN         NaN
# 4        27.0  ...            False             NaN         NaN
# 5        32.0  ...            False             NaN         NaN
#
#   contraband_found stop_outcome is_arrested stop_duration  out_of_state  \
# 0            False     Citation       False      0-15 Min         False
# 1            False     Citation       False     16-30 Min         False
# 3            False     Citation       False      0-15 Min         False
# 4            False     Citation       False      0-15 Min         False
# 5            False     Citation       False       30+ Min          True
#
#   drugs_related_stop  district
# 0              False   Zone K1
# 1              False   Zone X4
# 3              False   Zone X4
# 4              False   Zone X4
# 5              False   Zone X1
#
# [5 rows x 24 columns]

# %%
df["stop_date"].dtypes
# Out:
# dtype('O')

# %%
df["stop_time"].dtypes
# Out:
# dtype('O')

# %%
df["stop_date"]+ " "+df["stop_time"]
# Out:
# 0         2005-01-02 01:55
# 1         2005-01-02 20:30
# 3         2005-01-04 12:55
# 4         2005-01-06 01:30
# 5         2005-01-12 08:05
#                 ...
# 509666    2015-12-31 22:46
# 509667    2015-12-31 22:47
# 509668    2015-12-31 23:08
# 509669    2015-12-31 23:44
# 509670    2015-12-31 23:48
# Length: 480584, dtype: object

# %%
(df["stop_date"]+ " "+df["stop_time"]).dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df["stop_date"]+ " "+df["stop_time"])
# Out:
# 0        2005-01-02 01:55:00
# 1        2005-01-02 20:30:00
# 3        2005-01-04 12:55:00
# 4        2005-01-06 01:30:00
# 5        2005-01-12 08:05:00
#                  ...
# 509666   2015-12-31 22:46:00
# 509667   2015-12-31 22:47:00
# 509668   2015-12-31 23:08:00
# 509669   2015-12-31 23:44:00
# 509670   2015-12-31 23:48:00
# Length: 480584, dtype: datetime64[ns]

# %%
df["stop_datetime"] = pd.to_datetime(df["stop_date"]+ " "+df["stop_time"])
# Out:
# <ipython-input-255-f89d1e6b1cd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stop_datetime"] = pd.to_datetime(df["stop_date"]+ " "+df["stop_time"])

# %%
df["stop_datetime"]
# Out:
# 0        2005-01-02 01:55:00
# 1        2005-01-02 20:30:00
# 3        2005-01-04 12:55:00
# 4        2005-01-06 01:30:00
# 5        2005-01-12 08:05:00
#                  ...
# 509666   2015-12-31 22:46:00
# 509667   2015-12-31 22:47:00
# 509668   2015-12-31 23:08:00
# 509669   2015-12-31 23:44:00
# 509670   2015-12-31 23:48:00
# Name: stop_datetime, Length: 480584, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# id                               object
# stop_date                        object
# stop_time                        object
# location_raw                     object
# county_fips                     float64
# fine_grained_location           float64
# police_department                object
# driver_gender                    object
# driver_age_raw                  float64
# driver_age                      float64
# driver_race_raw                  object
# driver_race                      object
# violation_raw                    object
# violation                        object
# search_conducted                 object
# search_type_raw                  object
# search_type                      object
# contraband_found                   bool
# stop_outcome                     object
# is_arrested                        bool
# stop_duration                    object
# out_of_state                     object
# drugs_related_stop                 bool
# district                         object
# stop_datetime            datetime64[ns]
# dtype: object

# %%
df
# Out:
#                    id   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006  2005-01-12     08:05      Zone X1          NaN
# ...               ...         ...       ...          ...          ...
# 509666  RI-2015-47061  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065  2015-12-31     23:48      Zone K3          NaN
#
#         fine_grained_location police_department driver_gender  driver_age_raw  \
# 0                         NaN               600             M          1985.0
# 1                         NaN               500             M          1987.0
# 3                         NaN               500             M          1986.0
# 4                         NaN               500             M          1978.0
# 5                         NaN                 0             M          1973.0
# ...                       ...               ...           ...             ...
# 509666                    NaN               0.0             M          1959.0
# 509667                    NaN             500.0             M          1988.0
# 509668                    NaN             200.0             M          1980.0
# 509669                    NaN             900.0             M          1984.0
# 509670                    NaN             300.0             M          1988.0
#
#         driver_age  ... search_type_raw search_type contraband_found  \
# 0             20.0  ...             NaN         NaN            False
# 1             18.0  ...             NaN         NaN            False
# 3             19.0  ...             NaN         NaN            False
# 4             27.0  ...             NaN         NaN            False
# 5             32.0  ...             NaN         NaN            False
# ...            ...  ...             ...         ...              ...
# 509666        56.0  ...             NaN         NaN            False
# 509667        27.0  ...             NaN         NaN            False
# 509668        35.0  ...             NaN         NaN            False
# 509669        31.0  ...             NaN         NaN            False
# 509670        27.0  ...             NaN         NaN            False
#
#        stop_outcome is_arrested stop_duration out_of_state  \
# 0          Citation       False      0-15 Min        False
# 1          Citation       False     16-30 Min        False
# 3          Citation       False      0-15 Min        False
# 4          Citation       False      0-15 Min        False
# 5          Citation       False       30+ Min         True
# ...             ...         ...           ...          ...
# 509666     Citation       False      0-15 Min         True
# 509667     Citation       False      0-15 Min        False
# 509668     Citation       False      0-15 Min        False
# 509669     Citation       False      0-15 Min        False
# 509670     Citation       False      0-15 Min        False
#
#         drugs_related_stop district       stop_datetime
# 0                    False  Zone K1 2005-01-02 01:55:00
# 1                    False  Zone X4 2005-01-02 20:30:00
# 3                    False  Zone X4 2005-01-04 12:55:00
# 4                    False  Zone X4 2005-01-06 01:30:00
# 5                    False  Zone X1 2005-01-12 08:05:00
# ...                    ...      ...                 ...
# 509666               False  Zone X1 2015-12-31 22:46:00
# 509667               False  Zone X4 2015-12-31 22:47:00
# 509668               False  Zone X3 2015-12-31 23:08:00
# 509669               False  Zone K2 2015-12-31 23:44:00
# 509670               False  Zone K3 2015-12-31 23:48:00
#
# [480584 rows x 25 columns]

# %% [markdown]
# The last step that you'll take in this chapter is to set the ``stop_datetime`` column as the ``DataFrame``'s index. By replacing the default index with a ``DatetimeIndex``, you'll make it easier to analyze the dataset by date and time, which will come in handy later in the course.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Set ``stop_datetime`` as the ``DataFrame`` index.
# *   Examine the index to verify that it is a ``DatetimeIndex``.
# *   Examine the ``DataFrame`` columns to confirm that ``stop_datetime`` is no longer one of the columns.

# %%
df = df.set_index("stop_datetime")

# %%
df
# Out:
#                                 id   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006  2005-01-12     08:05      Zone X1
# ...                            ...         ...       ...          ...
# 2015-12-31 22:46:00  RI-2015-47061  2015-12-31     22:46      Zone X1
# 2015-12-31 22:47:00  RI-2015-47062  2015-12-31     22:47      Zone X4
# 2015-12-31 23:08:00  RI-2015-47063  2015-12-31     23:08      Zone X3
# 2015-12-31 23:44:00  RI-2015-47064  2015-12-31     23:44      Zone K2
# 2015-12-31 23:48:00  RI-2015-47065  2015-12-31     23:48      Zone K3
#
#                      county_fips  fine_grained_location police_department  \
# stop_datetime
# 2005-01-02 01:55:00          NaN                    NaN               600
# 2005-01-02 20:30:00          NaN                    NaN               500
# 2005-01-04 12:55:00          NaN                    NaN               500
# 2005-01-06 01:30:00          NaN                    NaN               500
# 2005-01-12 08:05:00          NaN                    NaN                 0
# ...                          ...                    ...               ...
# 2015-12-31 22:46:00          NaN                    NaN               0.0
# 2015-12-31 22:47:00          NaN                    NaN             500.0
# 2015-12-31 23:08:00          NaN                    NaN             200.0
# 2015-12-31 23:44:00          NaN                    NaN             900.0
# 2015-12-31 23:48:00          NaN                    NaN             300.0
#
#                     driver_gender  driver_age_raw  driver_age  ...  \
# stop_datetime                                                  ...
# 2005-01-02 01:55:00             M          1985.0        20.0  ...
# 2005-01-02 20:30:00             M          1987.0        18.0  ...
# 2005-01-04 12:55:00             M          1986.0        19.0  ...
# 2005-01-06 01:30:00             M          1978.0        27.0  ...
# 2005-01-12 08:05:00             M          1973.0        32.0  ...
# ...                           ...             ...         ...  ...
# 2015-12-31 22:46:00             M          1959.0        56.0  ...
# 2015-12-31 22:47:00             M          1988.0        27.0  ...
# 2015-12-31 23:08:00             M          1980.0        35.0  ...
# 2015-12-31 23:44:00             M          1984.0        31.0  ...
# 2015-12-31 23:48:00             M          1988.0        27.0  ...
#
#                     search_conducted search_type_raw search_type  \
# stop_datetime
# 2005-01-02 01:55:00            False             NaN         NaN
# 2005-01-02 20:30:00            False             NaN         NaN
# 2005-01-04 12:55:00            False             NaN         NaN
# 2005-01-06 01:30:00            False             NaN         NaN
# 2005-01-12 08:05:00            False             NaN         NaN
# ...                              ...             ...         ...
# 2015-12-31 22:46:00            False             NaN         NaN
# 2015-12-31 22:47:00            False             NaN         NaN
# 2015-12-31 23:08:00            False             NaN         NaN
# 2015-12-31 23:44:00            False             NaN         NaN
# 2015-12-31 23:48:00            False             NaN         NaN
#
#                     contraband_found stop_outcome is_arrested stop_duration  \
# stop_datetime
# 2005-01-02 01:55:00            False     Citation       False      0-15 Min
# 2005-01-02 20:30:00            False     Citation       False     16-30 Min
# 2005-01-04 12:55:00            False     Citation       False      0-15 Min
# 2005-01-06 01:30:00            False     Citation       False      0-15 Min
# 2005-01-12 08:05:00            False     Citation       False       30+ Min
# ...                              ...          ...         ...           ...
# 2015-12-31 22:46:00            False     Citation       False      0-15 Min
# 2015-12-31 22:47:00            False     Citation       False      0-15 Min
# 2015-12-31 23:08:00            False     Citation       False      0-15 Min
# 2015-12-31 23:44:00            False     Citation       False      0-15 Min
# 2015-12-31 23:48:00            False     Citation       False      0-15 Min
#
#                      out_of_state drugs_related_stop  district
# stop_datetime
# 2005-01-02 01:55:00         False              False   Zone K1
# 2005-01-02 20:30:00         False              False   Zone X4
# 2005-01-04 12:55:00         False              False   Zone X4
# 2005-01-06 01:30:00         False              False   Zone X4
# 2005-01-12 08:05:00          True              False   Zone X1
# ...                           ...                ...       ...
# 2015-12-31 22:46:00          True              False   Zone X1
# 2015-12-31 22:47:00         False              False   Zone X4
# 2015-12-31 23:08:00         False              False   Zone X3
# 2015-12-31 23:44:00         False              False   Zone K2
# 2015-12-31 23:48:00         False              False   Zone K3
#
# [480584 rows x 24 columns]

# %%
df.to_csv("police1.csv", sep='\t', encoding='utf-8')
